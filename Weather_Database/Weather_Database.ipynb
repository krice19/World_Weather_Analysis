# %%
import random
import numpy as np
from citipy import citipy
import pandas as pd
import matplotlib.pyplot as plt
import requests
from datetime import datetime
from config import weather_api_key

# %%
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

# %%
lat_lngs = zip(lats,lngs)

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
url = "http://api.openweathermap.org/data/2.5/weather?&units=imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | eyl
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | victoria
# Processing Record 7 of Set 1 | necochea
# Processing Record 8 of Set 1 | olafsvik
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | tual
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | benidorm
# Processing Record 18 of Set 1 | charlestown
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | haines junction
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | adrar
# Processing Record 24 of Set 1 | bandarbeyla
# Processing Record 25 of Set 1 | gat
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | stornoway
# Processing Record 28 of Set 1 | hellin
# Processing Record 29 of Set 1 | provideniya
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | palora
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | atambua
# Processing Record 35 of Set 1 | fort nelson
# Processing Record 36 of Set 1 | oranjemund
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | saint-francois
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | airai
# Processing Record 44 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 1 | leningradskiy
# Processing Record 48 of Set 1 | meulaboh
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | severo-kurilsk
# Processing Record 1 of Set 2 | batemans bay
# Processing Record 2 of Set 2 | santiago del estero
# Processing Record 3 of Set 2 | chuy
# Processing Record 4 of Set 2 | jining
# Processing Record 5 of Set 2 | metro
# Processing Record 6 of Set 2 | salalah
# Processing Record 7 of Set 2 | lebu
# Processing Record 8 of Set 2 | solnechnyy
# Processing Record 9 of Set 2 | shahr-e kord
# Processing Record 10 of Set 2 | pasni
# Processing Record 11 of Set 2 | lilongwe
# Processing Record 12 of Set 2 | yanam
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | hovd
# Processing Record 16 of Set 2 | hasaki
# Processing Record 17 of Set 2 | kieta
# Processing Record 18 of Set 2 | gorin
# Processing Record 19 of Set 2 | korhogo
# Processing Record 20 of Set 2 | coracora
# Processing Record 21 of Set 2 | clyde river
# Processing Record 22 of Set 2 | avila
# Processing Record 23 of Set 2 | dafeng
# Processing Record 24 of Set 2 | kuching
# Processing Record 25 of Set 2 | port hardy
# Processing Record 26 of Set 2 | khasan
# Processing Record 27 of Set 2 | malazgirt
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | berlevag
# Processing Record 30 of Set 2 | galveston
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | kosmynino
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | okha
# Processing Record 35 of Set 2 | albany
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | srednekolymsk
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | emba
# Processing Record 40 of Set 2 | robertsport
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | taltal
# Processing Record 43 of Set 2 | lompoc
# Processing Record 44 of Set 2 | tyrma
# Processing Record 45 of Set 2 | sur
# Processing Record 46 of Set 2 | tura
# Processing Record 47 of Set 2 | nelson bay
# Processing Record 48 of Set 2 | la macarena
# Processing Record 49 of Set 2 | broome
# Processing Record 50 of Set 2 | narsaq
# Processing Record 1 of Set 3 | tomatlan
# Processing Record 2 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 3 | jumla
# Processing Record 4 of Set 3 | port keats
# Processing Record 5 of Set 3 | aksu
# Processing Record 6 of Set 3 | paamiut
# Processing Record 7 of Set 3 | boyolangu
# Processing Record 8 of Set 3 | mpongwe
# Processing Record 9 of Set 3 | xining
# Processing Record 10 of Set 3 | port lincoln
# Processing Record 11 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | flinders
# Processing Record 14 of Set 3 | toyooka
# Processing Record 15 of Set 3 | havoysund
# Processing Record 16 of Set 3 | praia da vitoria
# Processing Record 17 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 3 | bad doberan
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | san cristobal
# Processing Record 21 of Set 3 | marsa matruh
# Processing Record 22 of Set 3 | san quintin
# Processing Record 23 of Set 3 | burns lake
# Processing Record 24 of Set 3 | hilo
# Processing Record 25 of Set 3 | klaksvik
# Processing Record 26 of Set 3 | laguna
# Processing Record 27 of Set 3 | aklavik
# Processing Record 28 of Set 3 | smithers
# Processing Record 29 of Set 3 | pyshchug
# Processing Record 30 of Set 3 | port hedland
# Processing Record 31 of Set 3 | saint-philippe
# Processing Record 32 of Set 3 | mayuge
# Processing Record 33 of Set 3 | puerto cabezas
# Processing Record 34 of Set 3 | whitehorse
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 3 | christchurch
# Processing Record 38 of Set 3 | drawsko pomorskie
# Processing Record 39 of Set 3 | sorong
# Processing Record 40 of Set 3 | iqaluit
# Processing Record 41 of Set 3 | shelburne
# Processing Record 42 of Set 3 | norman wells
# Processing Record 43 of Set 3 | upernavik
# Processing Record 44 of Set 3 | baruun-urt
# Processing Record 45 of Set 3 | pisco
# Processing Record 46 of Set 3 | harlingen
# Processing Record 47 of Set 3 | alekseyevsk
# Processing Record 48 of Set 3 | tuktoyaktuk
# Processing Record 49 of Set 3 | yulara
# Processing Record 50 of Set 3 | pushkinskiye gory
# Processing Record 1 of Set 4 | wanaka
# Processing Record 2 of Set 4 | ouallam
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | saskylakh
# Processing Record 6 of Set 4 | khatanga
# Processing Record 7 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 4 | bubaque
# Processing Record 9 of Set 4 | sitka
# Processing Record 10 of Set 4 | pedasi
# Processing Record 11 of Set 4 | mezen
# Processing Record 12 of Set 4 | chernyshevsk
# Processing Record 13 of Set 4 | tiksi
# Processing Record 14 of Set 4 | faanui
# Processing Record 15 of Set 4 | limanu
# Processing Record 16 of Set 4 | hobart
# Processing Record 17 of Set 4 | cabo san lucas
# Processing Record 18 of Set 4 | vila franca do campo
# Processing Record 19 of Set 4 | katsuura
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | nanortalik
# Processing Record 22 of Set 4 | butaritari
# Processing Record 23 of Set 4 | los llanos de aridane
# Processing Record 24 of Set 4 | ancud
# Processing Record 25 of Set 4 | anloga
# Processing Record 26 of Set 4 | atuona
# Processing Record 27 of Set 4 | arlit
# Processing Record 28 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 4 | san juan
# Processing Record 30 of Set 4 | minab
# Processing Record 31 of Set 4 | damghan
# Processing Record 32 of Set 4 | steinbach
# Processing Record 33 of Set 4 | kenai
# Processing Record 34 of Set 4 | dhaka
# Processing Record 35 of Set 4 | tilichiki
# Processing Record 36 of Set 4 | chulman
# Processing Record 37 of Set 4 | geraldton
# Processing Record 38 of Set 4 | palasa
# Processing Record 39 of Set 4 | east london
# Processing Record 40 of Set 4 | pacific grove
# Processing Record 41 of Set 4 | chokurdakh
# Processing Record 42 of Set 4 | bela palanka
# Processing Record 43 of Set 4 | mapulot
# Processing Record 44 of Set 4 | berezovyy
# Processing Record 45 of Set 4 | gland
# Processing Record 46 of Set 4 | touros
# Processing Record 47 of Set 4 | mahajanga
# Processing Record 48 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 4 | comodoro rivadavia
# Processing Record 50 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 5 | alboraya
# Processing Record 2 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 5 | kaitangata
# Processing Record 4 of Set 5 | sao joao da barra
# Processing Record 5 of Set 5 | cavalcante
# Processing Record 6 of Set 5 | surgut
# Processing Record 7 of Set 5 | broken hill
# Processing Record 8 of Set 5 | praya
# Processing Record 9 of Set 5 | bathsheba
# Processing Record 10 of Set 5 | ugoofaaru
# Processing Record 11 of Set 5 | komsomolskiy
# Processing Record 12 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 5 | itambe
# Processing Record 14 of Set 5 | saint combs
# City not found. Skipping...
# Processing Record 15 of Set 5 | longyearbyen
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | qaanaaq
# Processing Record 18 of Set 5 | jacareacanga
# Processing Record 19 of Set 5 | vredendal
# Processing Record 20 of Set 5 | bambous virieux
# Processing Record 21 of Set 5 | kardasova recice
# Processing Record 22 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 5 | bhakkar
# Processing Record 24 of Set 5 | sangar
# Processing Record 25 of Set 5 | hambantota
# Processing Record 26 of Set 5 | hami
# Processing Record 27 of Set 5 | harper
# Processing Record 28 of Set 5 | magadan
# Processing Record 29 of Set 5 | moultonborough
# Processing Record 30 of Set 5 | kahului
# Processing Record 31 of Set 5 | grindavik
# Processing Record 32 of Set 5 | takoradi
# Processing Record 33 of Set 5 | fortuna
# Processing Record 34 of Set 5 | saldanha
# Processing Record 35 of Set 5 | ilulissat
# Processing Record 36 of Set 5 | pangnirtung
# Processing Record 37 of Set 5 | bilibino
# Processing Record 38 of Set 5 | starogard gdanski
# Processing Record 39 of Set 5 | kenora
# Processing Record 40 of Set 5 | gonbad-e qabus
# Processing Record 41 of Set 5 | kavieng
# Processing Record 42 of Set 5 | high level
# Processing Record 43 of Set 5 | esso
# Processing Record 44 of Set 5 | north platte
# Processing Record 45 of Set 5 | maragogi
# Processing Record 46 of Set 5 | atasu
# Processing Record 47 of Set 5 | gondanglegi
# Processing Record 48 of Set 5 | guerrero negro
# Processing Record 49 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 5 | barrow
# Processing Record 1 of Set 6 | samarai
# Processing Record 2 of Set 6 | seoul
# Processing Record 3 of Set 6 | khandagayty
# Processing Record 4 of Set 6 | syasstroy
# Processing Record 5 of Set 6 | kruisfontein
# Processing Record 6 of Set 6 | kvitok
# Processing Record 7 of Set 6 | carndonagh
# Processing Record 8 of Set 6 | baykit
# Processing Record 9 of Set 6 | quesnel
# Processing Record 10 of Set 6 | port macquarie
# Processing Record 11 of Set 6 | darab
# Processing Record 12 of Set 6 | torbay
# Processing Record 13 of Set 6 | horadiz
# Processing Record 14 of Set 6 | drahovo
# Processing Record 15 of Set 6 | khor
# Processing Record 16 of Set 6 | mandera
# Processing Record 17 of Set 6 | esperance
# Processing Record 18 of Set 6 | half moon bay
# Processing Record 19 of Set 6 | kez
# Processing Record 20 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 6 | kita
# Processing Record 22 of Set 6 | sao sebastiao
# Processing Record 23 of Set 6 | callaguip
# Processing Record 24 of Set 6 | hirara
# Processing Record 25 of Set 6 | lagoa
# Processing Record 26 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 6 | anadyr
# Processing Record 28 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 29 of Set 6 | sao miguel do araguaia
# Processing Record 30 of Set 6 | bam
# Processing Record 31 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 32 of Set 6 | iranshahr
# Processing Record 33 of Set 6 | fairbanks
# Processing Record 34 of Set 6 | mareeba
# Processing Record 35 of Set 6 | rawson
# Processing Record 36 of Set 6 | mwinilunga
# Processing Record 37 of Set 6 | druzhba
# Processing Record 38 of Set 6 | sebastian
# Processing Record 39 of Set 6 | kalmunai
# Processing Record 40 of Set 6 | nokaneng
# Processing Record 41 of Set 6 | fare
# Processing Record 42 of Set 6 | souillac
# Processing Record 43 of Set 6 | dingle
# Processing Record 44 of Set 6 | lorengau
# Processing Record 45 of Set 6 | mayumba
# Processing Record 46 of Set 6 | beringovskiy
# Processing Record 47 of Set 6 | namatanai
# Processing Record 48 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 6 | otradnoye
# Processing Record 50 of Set 6 | puerto carreno
# Processing Record 1 of Set 7 | oranjestad
# Processing Record 2 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 7 | sharjah
# Processing Record 4 of Set 7 | la palma
# Processing Record 5 of Set 7 | ahuimanu
# Processing Record 6 of Set 7 | taoudenni
# Processing Record 7 of Set 7 | ostrovnoy
# Processing Record 8 of Set 7 | sao filipe
# Processing Record 9 of Set 7 | krasnousolskiy
# City not found. Skipping...
# Processing Record 10 of Set 7 | ayan
# Processing Record 11 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 7 | kendari
# Processing Record 13 of Set 7 | ocampo
# Processing Record 14 of Set 7 | tapes
# Processing Record 15 of Set 7 | russell
# Processing Record 16 of Set 7 | coihaique
# Processing Record 17 of Set 7 | meadow lake
# Processing Record 18 of Set 7 | san vicente de canete
# Processing Record 19 of Set 7 | am timan
# Processing Record 20 of Set 7 | pires do rio
# Processing Record 21 of Set 7 | verkhniy avzyan
# Processing Record 22 of Set 7 | sechura
# Processing Record 23 of Set 7 | omsukchan
# Processing Record 24 of Set 7 | campos gerais
# Processing Record 25 of Set 7 | yenagoa
# Processing Record 26 of Set 7 | cherskiy
# Processing Record 27 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 7 | eureka
# Processing Record 29 of Set 7 | halifax
# Processing Record 30 of Set 7 | abu zabad
# Processing Record 31 of Set 7 | el tigre
# Processing Record 32 of Set 7 | mrkonjic grad
# Processing Record 33 of Set 7 | isangel
# Processing Record 34 of Set 7 | athens
# Processing Record 35 of Set 7 | loiza
# Processing Record 36 of Set 7 | tautira
# Processing Record 37 of Set 7 | yar-sale
# Processing Record 38 of Set 7 | namibe
# Processing Record 39 of Set 7 | dakar
# Processing Record 40 of Set 7 | scarborough
# Processing Record 41 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 42 of Set 7 | sunrise manor
# Processing Record 43 of Set 7 | bagdarin
# Processing Record 44 of Set 7 | vardo
# Processing Record 45 of Set 7 | bodden town
# Processing Record 46 of Set 7 | karratha
# Processing Record 47 of Set 7 | cayenne
# Processing Record 48 of Set 7 | vanimo
# Processing Record 49 of Set 7 | sola
# Processing Record 50 of Set 7 | pauini
# Processing Record 1 of Set 8 | asau
# Processing Record 2 of Set 8 | palmer
# Processing Record 3 of Set 8 | balkanabat
# Processing Record 4 of Set 8 | kapustin yar-1
# City not found. Skipping...
# Processing Record 5 of Set 8 | vestmannaeyjar
# Processing Record 6 of Set 8 | nova vcelnice
# Processing Record 7 of Set 8 | bang saphan
# Processing Record 8 of Set 8 | naze
# Processing Record 9 of Set 8 | beruwala
# Processing Record 10 of Set 8 | qiongshan
# Processing Record 11 of Set 8 | oktyabrskoye
# Processing Record 12 of Set 8 | upata
# Processing Record 13 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 14 of Set 8 | lianzhou
# Processing Record 15 of Set 8 | mosquera
# Processing Record 16 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 8 | thunder bay
# Processing Record 18 of Set 8 | margate
# Processing Record 19 of Set 8 | verkhnetulomskiy
# Processing Record 20 of Set 8 | tucuma
# Processing Record 21 of Set 8 | killybegs
# Processing Record 22 of Set 8 | malangwa
# Processing Record 23 of Set 8 | weligama
# Processing Record 24 of Set 8 | anito
# Processing Record 25 of Set 8 | panama city
# Processing Record 26 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 27 of Set 8 | manzil tamim
# City not found. Skipping...
# Processing Record 28 of Set 8 | byron bay
# Processing Record 29 of Set 8 | zhigansk
# Processing Record 30 of Set 8 | lasa
# Processing Record 31 of Set 8 | rorvik
# Processing Record 32 of Set 8 | talcahuano
# Processing Record 33 of Set 8 | mayo
# Processing Record 34 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 8 | soto la marina
# Processing Record 36 of Set 8 | linjiang
# Processing Record 37 of Set 8 | bonthe
# Processing Record 38 of Set 8 | petropavlovka
# Processing Record 39 of Set 8 | mahibadhoo
# Processing Record 40 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 8 | presidencia roque saenz pena
# Processing Record 42 of Set 8 | maturin
# Processing Record 43 of Set 8 | usinsk
# Processing Record 44 of Set 8 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 45 of Set 8 | khandyga
# Processing Record 46 of Set 8 | hidalgotitlan
# Processing Record 47 of Set 8 | flin flon
# Processing Record 48 of Set 8 | lata
# Processing Record 49 of Set 8 | codrington
# Processing Record 50 of Set 8 | loharu
# Processing Record 1 of Set 9 | makat
# Processing Record 2 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 3 of Set 9 | chicama
# Processing Record 4 of Set 9 | tuatapere
# Processing Record 5 of Set 9 | stony plain
# Processing Record 6 of Set 9 | yumen
# Processing Record 7 of Set 9 | kungurtug
# Processing Record 8 of Set 9 | sorland
# Processing Record 9 of Set 9 | erenhot
# Processing Record 10 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 9 | verkhniye kigi
# Processing Record 12 of Set 9 | husavik
# Processing Record 13 of Set 9 | pozhva
# Processing Record 14 of Set 9 | qui nhon
# Processing Record 15 of Set 9 | manthani
# Processing Record 16 of Set 9 | maceio
# Processing Record 17 of Set 9 | ust-ordynskiy
# Processing Record 18 of Set 9 | okato
# Processing Record 19 of Set 9 | coquimbo
# Processing Record 20 of Set 9 | alofi
# Processing Record 21 of Set 9 | liwale
# Processing Record 22 of Set 9 | hamilton
# Processing Record 23 of Set 9 | saint anthony
# Processing Record 24 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 25 of Set 9 | santiago
# Processing Record 26 of Set 9 | sabzevar
# Processing Record 27 of Set 9 | bang rakam
# Processing Record 28 of Set 9 | manakara
# Processing Record 29 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 9 | skibbereen
# Processing Record 31 of Set 9 | maningrida
# Processing Record 32 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 9 | avera
# Processing Record 34 of Set 9 | mabaruma
# Processing Record 35 of Set 9 | havre-saint-pierre
# Processing Record 36 of Set 9 | gerash
# Processing Record 37 of Set 9 | zyryanka
# Processing Record 38 of Set 9 | victoria point
# Processing Record 39 of Set 9 | donnacona
# Processing Record 40 of Set 9 | zhongxing
# Processing Record 41 of Set 9 | lavrentiya
# Processing Record 42 of Set 9 | carballo
# Processing Record 43 of Set 9 | ponca city
# Processing Record 44 of Set 9 | aguimes
# Processing Record 45 of Set 9 | boende
# Processing Record 46 of Set 9 | qaqortoq
# Processing Record 47 of Set 9 | la ronge
# Processing Record 48 of Set 9 | gornyye klyuchi
# Processing Record 49 of Set 9 | kysyl-syr
# Processing Record 50 of Set 9 | ust-tsilma
# Processing Record 1 of Set 10 | abalak
# Processing Record 2 of Set 10 | vilyuysk
# Processing Record 3 of Set 10 | soyo
# Processing Record 4 of Set 10 | west odessa
# Processing Record 5 of Set 10 | nyimba
# Processing Record 6 of Set 10 | hofn
# Processing Record 7 of Set 10 | magistralnyy
# Processing Record 8 of Set 10 | gualaquiza
# Processing Record 9 of Set 10 | monywa
# Processing Record 10 of Set 10 | is
# City not found. Skipping...
# Processing Record 11 of Set 10 | kupang
# Processing Record 12 of Set 10 | almaty
# Processing Record 13 of Set 10 | ponta do sol
# Processing Record 14 of Set 10 | lensk
# Processing Record 15 of Set 10 | dok kham tai
# Processing Record 16 of Set 10 | tsumeb
# Processing Record 17 of Set 10 | manuk mangkaw
# Processing Record 18 of Set 10 | buin
# Processing Record 19 of Set 10 | lazaro cardenas
# Processing Record 20 of Set 10 | ippy
# Processing Record 21 of Set 10 | yerbogachen
# Processing Record 22 of Set 10 | mehamn
# Processing Record 23 of Set 10 | duncan
# Processing Record 24 of Set 10 | gao
# Processing Record 25 of Set 10 | marsh harbour
# Processing Record 26 of Set 10 | noumea
# Processing Record 27 of Set 10 | porto novo
# Processing Record 28 of Set 10 | kota belud
# Processing Record 29 of Set 10 | muyezerskiy
# Processing Record 30 of Set 10 | chabahar
# Processing Record 31 of Set 10 | lugovoy
# Processing Record 32 of Set 10 | cap malheureux
# Processing Record 33 of Set 10 | wadi maliz
# Processing Record 34 of Set 10 | venado tuerto
# Processing Record 35 of Set 10 | beloha
# Processing Record 36 of Set 10 | barcelos
# Processing Record 37 of Set 10 | uige
# Processing Record 38 of Set 10 | espanola
# Processing Record 39 of Set 10 | benguela
# Processing Record 40 of Set 10 | coahuayana
# Processing Record 41 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 10 | sabang
# Processing Record 44 of Set 10 | sochi
# Processing Record 45 of Set 10 | hvide sande
# Processing Record 46 of Set 10 | puerto madryn
# Processing Record 47 of Set 10 | ashland
# Processing Record 48 of Set 10 | bom jesus do galho
# Processing Record 49 of Set 10 | kangalassy
# Processing Record 50 of Set 10 | novyy urengoy
# Processing Record 1 of Set 11 | rio grande
# Processing Record 2 of Set 11 | traverse city
# Processing Record 3 of Set 11 | humaita
# Processing Record 4 of Set 11 | daru
# Processing Record 5 of Set 11 | toro
# Processing Record 6 of Set 11 | majene
# Processing Record 7 of Set 11 | mlonggo
# Processing Record 8 of Set 11 | loudeac
# Processing Record 9 of Set 11 | san patricio
# Processing Record 10 of Set 11 | ukiah
# Processing Record 11 of Set 11 | pangai
# Processing Record 12 of Set 11 | basco
# Processing Record 13 of Set 11 | williams lake
# Processing Record 14 of Set 11 | yeovil
# Processing Record 15 of Set 11 | bonavista
# Processing Record 16 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 17 of Set 11 | port blair
# Processing Record 18 of Set 11 | saint-louis
# Processing Record 19 of Set 11 | nishihara
# Processing Record 20 of Set 11 | evensk
# Processing Record 21 of Set 11 | eston
# Processing Record 22 of Set 11 | aurillac
# Processing Record 23 of Set 11 | xichang
# Processing Record 24 of Set 11 | talara
# Processing Record 25 of Set 11 | bartica
# Processing Record 26 of Set 11 | bella vista
# Processing Record 27 of Set 11 | henties bay
# Processing Record 28 of Set 11 | petatlan
# Processing Record 29 of Set 11 | gilbert
# Processing Record 30 of Set 11 | hobyo
# Processing Record 31 of Set 11 | almora
# Processing Record 32 of Set 11 | matara
# Processing Record 33 of Set 11 | labrea
# Processing Record 34 of Set 11 | takapau
# Processing Record 35 of Set 11 | vaitape
# Processing Record 36 of Set 11 | ocean city
# Processing Record 37 of Set 11 | novyye lyady
# Processing Record 38 of Set 11 | huarmey
# Processing Record 39 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 40 of Set 11 | anshan
# Processing Record 41 of Set 11 | portland
# Processing Record 42 of Set 11 | imeni babushkina
# Processing Record 43 of Set 11 | turukhansk
# Processing Record 44 of Set 11 | tabuk
# Processing Record 45 of Set 11 | wanning
# Processing Record 46 of Set 11 | sadon
# Processing Record 47 of Set 11 | babstovo
# Processing Record 48 of Set 11 | college
# Processing Record 49 of Set 11 | dalby
# Processing Record 50 of Set 11 | amapa
# Processing Record 1 of Set 12 | kundiawa
# Processing Record 2 of Set 12 | saint george
# Processing Record 3 of Set 12 | talnakh
# Processing Record 4 of Set 12 | tessalit
# Processing Record 5 of Set 12 | san andres
# Processing Record 6 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 12 | biak
# Processing Record 8 of Set 12 | viedma
# Processing Record 9 of Set 12 | shingu
# Processing Record 10 of Set 12 | crossville
# Processing Record 11 of Set 12 | konya
# Processing Record 12 of Set 12 | amahai
# Processing Record 13 of Set 12 | quatre cocos
# Processing Record 14 of Set 12 | semey
# Processing Record 15 of Set 12 | priboj
# Processing Record 16 of Set 12 | westport
# Processing Record 17 of Set 12 | telemaco borba
# Processing Record 18 of Set 12 | noshiro
# Processing Record 19 of Set 12 | trat
# Processing Record 20 of Set 12 | abha
# Processing Record 21 of Set 12 | palaikastron
# Processing Record 22 of Set 12 | camacupa
# Processing Record 23 of Set 12 | gorkovskoye
# City not found. Skipping...
# Processing Record 24 of Set 12 | kandrian
# Processing Record 25 of Set 12 | muzhi
# Processing Record 26 of Set 12 | great yarmouth
# Processing Record 27 of Set 12 | praia
# Processing Record 28 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 12 | maebaru
# Processing Record 30 of Set 12 | polyarnyye zori
# Processing Record 31 of Set 12 | nantucket
# Processing Record 32 of Set 12 | baracoa
# Processing Record 33 of Set 12 | edelira
# Processing Record 34 of Set 12 | mitsamiouli
# Processing Record 35 of Set 12 | dongsheng
# Processing Record 36 of Set 12 | the valley
# Processing Record 37 of Set 12 | palmaner
# Processing Record 38 of Set 12 | kirakira
# Processing Record 39 of Set 12 | verkhoyansk
# Processing Record 40 of Set 12 | lucapa
# Processing Record 41 of Set 12 | goderich
# Processing Record 42 of Set 12 | chara
# Processing Record 43 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 12 | nemuro
# Processing Record 45 of Set 12 | sinnamary
# Processing Record 46 of Set 12 | bundaberg
# Processing Record 47 of Set 12 | pampa
# Processing Record 48 of Set 12 | sao jose da coroa grande
# Processing Record 49 of Set 12 | east wenatchee bench
# Processing Record 50 of Set 12 | vila do maio
# Processing Record 1 of Set 13 | goianapolis
# Processing Record 2 of Set 13 | kamenka
# Processing Record 3 of Set 13 | dehui
# Processing Record 4 of Set 13 | banda aceh
# Processing Record 5 of Set 13 | ardahan
# Processing Record 6 of Set 13 | ellisras
# Processing Record 7 of Set 13 | bay saint louis
# Processing Record 8 of Set 13 | black river
# Processing Record 9 of Set 13 | alihe
# Processing Record 10 of Set 13 | kayerkan
# Processing Record 11 of Set 13 | bichura
# Processing Record 12 of Set 13 | cooma
# Processing Record 13 of Set 13 | moroni
# Processing Record 14 of Set 13 | nashville
# Processing Record 15 of Set 13 | dir
# Processing Record 16 of Set 13 | caraballeda
# Processing Record 17 of Set 13 | rotterdam
# Processing Record 18 of Set 13 | ambilobe
# Processing Record 19 of Set 13 | iskateley
# Processing Record 20 of Set 13 | solton
# Processing Record 21 of Set 13 | sioux lookout
# Processing Record 22 of Set 13 | ixtapa
# Processing Record 23 of Set 13 | zheleznodorozhnyy
# Processing Record 24 of Set 13 | guayaramerin
# Processing Record 25 of Set 13 | merrill
# Processing Record 26 of Set 13 | qasigiannguit
# Processing Record 27 of Set 13 | wisconsin rapids
# Processing Record 28 of Set 13 | raudeberg
# Processing Record 29 of Set 13 | puerto el triunfo
# Processing Record 30 of Set 13 | nizhniy kuranakh
# Processing Record 31 of Set 13 | lanzhou
# Processing Record 32 of Set 13 | batagay-alyta
# Processing Record 33 of Set 13 | chipata
# Processing Record 34 of Set 13 | catumbela
# Processing Record 35 of Set 13 | santa isabel
# Processing Record 36 of Set 13 | teahupoo
# Processing Record 37 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 13 | zhicheng
# Processing Record 39 of Set 13 | kingaroy
# Processing Record 40 of Set 13 | saint-joseph
# Processing Record 41 of Set 13 | ode
# Processing Record 42 of Set 13 | preobrazheniye
# Processing Record 43 of Set 13 | lerwick
# Processing Record 44 of Set 13 | inhambane
# Processing Record 45 of Set 13 | richards bay
# Processing Record 46 of Set 13 | west lafayette
# Processing Record 47 of Set 13 | sobolevo
# Processing Record 48 of Set 13 | ereymentau
# Processing Record 49 of Set 13 | matadi
# Processing Record 50 of Set 13 | murchison
# Processing Record 1 of Set 14 | youghal
# Processing Record 2 of Set 14 | vieux-habitants
# Processing Record 3 of Set 14 | lolodorf
# Processing Record 4 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 5 of Set 14 | batagay
# Processing Record 6 of Set 14 | kasane
# Processing Record 7 of Set 14 | kaduna
# Processing Record 8 of Set 14 | maraa
# Processing Record 9 of Set 14 | salmo
# Processing Record 10 of Set 14 | salisbury
# Processing Record 11 of Set 14 | furano
# Processing Record 12 of Set 14 | kango
# Processing Record 13 of Set 14 | safaga
# Processing Record 14 of Set 14 | kyren
# Processing Record 15 of Set 14 | udachnyy
# Processing Record 16 of Set 14 | pekalongan
# Processing Record 17 of Set 14 | skjervoy
# Processing Record 18 of Set 14 | charters towers
# Processing Record 19 of Set 14 | liku
# Processing Record 20 of Set 14 | mogocha
# Processing Record 21 of Set 14 | bossembele
# City not found. Skipping...
# Processing Record 22 of Set 14 | lanxi
# Processing Record 23 of Set 14 | egvekinot
# Processing Record 24 of Set 14 | lyantonde
# Processing Record 25 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 14 | senno
# Processing Record 27 of Set 14 | islahiye
# Processing Record 28 of Set 14 | ludvika
# Processing Record 29 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 14 | aksay
# Processing Record 31 of Set 14 | leh
# Processing Record 32 of Set 14 | petrolandia
# City not found. Skipping...
# Processing Record 33 of Set 14 | kaputa
# Processing Record 34 of Set 14 | lumberton
# Processing Record 35 of Set 14 | sherghati
# Processing Record 36 of Set 14 | blagoyevo
# Processing Record 37 of Set 14 | ponoka
# Processing Record 38 of Set 14 | catamarca
# Processing Record 39 of Set 14 | methoni
# Processing Record 40 of Set 14 | shepsi
# Processing Record 41 of Set 14 | uk
# City not found. Skipping...
# Processing Record 42 of Set 14 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 43 of Set 14 | mazatlan
# Processing Record 44 of Set 14 | bac lieu
# Processing Record 45 of Set 14 | sainte-maxime
# Processing Record 46 of Set 14 | montague
# Processing Record 47 of Set 14 | calvia
# Processing Record 48 of Set 14 | geilo
# Processing Record 49 of Set 14 | la tuque
# Processing Record 50 of Set 14 | severodvinsk
# Processing Record 1 of Set 15 | nuuk
# Processing Record 2 of Set 15 | kloulklubed
# Processing Record 3 of Set 15 | goulburn
# Processing Record 4 of Set 15 | yeniseysk
# Processing Record 5 of Set 15 | songea
# Processing Record 6 of Set 15 | ko samui
# Processing Record 7 of Set 15 | machiques
# Processing Record 8 of Set 15 | mount isa
# Processing Record 9 of Set 15 | sawakin
# Processing Record 10 of Set 15 | ulagan
# Processing Record 11 of Set 15 | algiers
# Processing Record 12 of Set 15 | gizo
# Processing Record 13 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 14 of Set 15 | ahipara
# Processing Record 15 of Set 15 | voyvozh
# Processing Record 16 of Set 15 | novo oriente
# Processing Record 17 of Set 15 | pareora
# Processing Record 18 of Set 15 | faya
# Processing Record 19 of Set 15 | wasco
# Processing Record 20 of Set 15 | moron
# Processing Record 21 of Set 15 | paita
# Processing Record 22 of Set 15 | taranagar
# Processing Record 23 of Set 15 | mailsi
# Processing Record 24 of Set 15 | newport
# Processing Record 25 of Set 15 | el wasta
# City not found. Skipping...
# Processing Record 26 of Set 15 | port augusta
# Processing Record 27 of Set 15 | midland
# Processing Record 28 of Set 15 | xiaoweizhai
# Processing Record 29 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 15 | telimele
# Processing Record 31 of Set 15 | umm lajj
# Processing Record 32 of Set 15 | osa
# Processing Record 33 of Set 15 | malanje
# Processing Record 34 of Set 15 | mantua
# Processing Record 35 of Set 15 | windhoek
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Vaini -21.2000 -175.2000     69.96        94          20
# 1        Rikitea -23.1203 -134.9692     72.23        60          98
# 2            Eyl   7.9803   49.8164     83.23        67          61
# 3    Port Alfred -33.5906   26.8910     66.33        68         100
# 4       Hermanus -34.4187   19.2345     64.80        66          86
# 5       Victoria  22.2855  114.1577     87.33        81          91
# 6       Necochea -38.5473  -58.7368     63.03        55          76
# 7       Olafsvik  64.8945  -23.7142     46.11        82          41
# 8   Puerto Ayora  -0.7393  -90.3518     76.96        94          65
# 9  Mar Del Plata -38.0023  -57.5575     64.09        48           0
#
#    Wind Speed Country Current Description
# 0        6.91      TO          few clouds
# 1       10.60      PF     overcast clouds
# 2       24.07      SO       broken clouds
# 3       12.55      ZA     overcast clouds
# 4       18.57      ZA     overcast clouds
# 5        5.01      HK     overcast clouds
# 6       16.84      AR       broken clouds
# 7        9.82      IS    scattered clouds
# 8        4.00      EC       broken clouds
# 9       14.00      AR           clear sky

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Vaini      TO -21.2000 -175.2000     69.96        94          20
# 1      Rikitea      PF -23.1203 -134.9692     72.23        60          98
# 2          Eyl      SO   7.9803   49.8164     83.23        67          61
# 3  Port Alfred      ZA -33.5906   26.8910     66.33        68         100
# 4     Hermanus      ZA -34.4187   19.2345     64.80        66          86
#
#    Wind Speed Current Description
# 0        6.91          few clouds
# 1       10.60     overcast clouds
# 2       24.07       broken clouds
# 3       12.55     overcast clouds
# 4       18.57     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
